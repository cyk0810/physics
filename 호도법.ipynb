# %% [markdown]
# <a href="https://colab.research.google.com/github/cyk0810/physics/blob/20250312/%ED%98%B8%EB%8F%84%EB%B2%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

angle_degree = 30

angle_radian = angle_degree * math.pi/180

print("angle_degree:", angle_radian)
# Out:
# angle_degree: 0.5235987755982988
